# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.1-70b-versatile",
    temperature=0,
    groq_api_key = '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'
    # other params...
)

def chat():
    userPrompt = input("Ask me something!")
    res = llm.invoke(userPrompt)
    print(res.content)
    if res.content:
        chat()

chat()
# Out:
# Ask me something! from langchain_groq import ChatGroq  # Initialize the chatbot with a specific model and temperature llm = ChatGroq(     model="llama-3.1-70b-versatile",     temperature=0.5,  # A higher temperature can lead to more empathetic responses     groq_api_key='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' )  def is_mental_health_question(prompt):     """     Checks if the user's prompt is related to mental health.     """     mental_health_keywords = ["mental health", "anxiety", "depression", "stress", "therapy", "counseling", "self-care"]     for keyword in mental_health_keywords:         if keyword.lower() in prompt.lower():             return True     return False  def chat():     # Provide a welcome message and some guidelines for the user     print("\n\nWelcome to our mental health support chatbot. We're here to listen and offer support.\n")     print("\n\nPlease keep in mind that we're not a substitute for professional help. If you're in crisis, please call a helpline or seek immediate assistance.\n")      while True:         # Get user input         userPrompt = input("Ask here! ")          # Check if the user's prompt is related to mental health         if not is_mental_health_question(userPrompt):             print("Sorry, our chatbot is only trained to answer mental health-related questions. Please try again.")             continue          # Prepend a prompt to the user's input to guide the model's response         mental_health_prompt = "\n\nI'm here to listen and offer support. Please respond with empathy and understanding. " + userPrompt          # Get the model's response         res = llm.invoke(mental_health_prompt)          # Print the model's response         print(res.content)          # Print a newline before the next user input         print()  chat()                                                                       Make this code to answer all mind related questions and avoid non mind related questions
# Here's an updated version of the code that answers all mind-related questions and avoids non-mind related questions:
#
# ```python
# from langchain_groq import ChatGroq
#
# # Initialize the chatbot with a specific model and temperature
# llm = ChatGroq(
#     model="llama-3.1-70b-versatile",
#     temperature=0.5,  # A higher temperature can lead to more empathetic responses
#     groq_api_key='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'
# )
#
# def is_mind_related_question(prompt):
#     """
#     Checks if the user's prompt is related to the mind.
#     """
#     mind_related_keywords = [
#         "mind", "brain", "thoughts", "feelings", "emotions", "mental health",
#         "anxiety", "depression", "stress", "therapy", "counseling", "self-care",
#         "motivation", "focus", "concentration", "memory", "learning", "intelligence"
#     ]
#     for keyword in mind_related_keywords:
#         if keyword.lower() in prompt.lower():
#             return True
#     return False
#
# def chat():
#     # Provide a welcome message and some guidelines for the user
#     print("\n\nWelcome to our mind support chatbot. We're here to listen and offer support.\n")
#     print("\n\nPlease keep in mind that we're not a substitute for professional help. If you're in crisis, please call a helpline or seek immediate assistance.\n")
#
#     while True:
#         # Get user input
#         userPrompt = input("Ask here! ")
#
#         # Check if the user's prompt is related to the mind
#         if not is_mind_related_question(userPrompt):
#             print("Sorry, our chatbot is only trained to answer mind-related questions. Please try again.")
#             continue
#
#         # Prepend a prompt to the user's input to guide the model's response
#         mind_related_prompt = "\n\nI'm here to listen and offer support. Please respond with empathy and understanding. " + userPrompt
#
#         # Get the model's response
#         res = llm.invoke(mind_related_prompt)
#
#         # Print the model's response
#         print(res.content)
#
#         # Print a newline before the next user input
#         print()
#
# chat()
# ```
#
# Here are the changes I made:
#
# 1. I updated the `is_mental_health_question` function to `is_mind_related_question` to reflect the broader scope of the chatbot.
# 2. I added more keywords to the `mind_related_keywords` list to cover a wider range of mind-related topics.
# 3. I updated the welcome message and guidelines to reflect the broader scope of the chatbot.
#
# With these changes, the chatbot should now answer all mind-related questions and avoid non-mind related questions.
# Ask me something! This code answers for question like depression but not other mind related question like how to overcome daydreaming or how to  stop overthinking.
# It seems like you're looking to expand the scope of your mental health-related code to cover a broader range of topics, including daydreaming and overthinking. Here's a possible approach to enhance your code:
#
# **Step 1: Define a Knowledge Base**
#
# Create a knowledge base that includes information on various mental health topics, including depression, anxiety, daydreaming, overthinking, and more. This knowledge base can be in the form of a dictionary or a database.
#
# **Step 2: Implement a Natural Language Processing (NLP) Module**
#
# Use an NLP library like NLTK or spaCy to analyze user input and identify the topic they're asking about. This module can help you determine whether the user is asking about depression, daydreaming, overthinking, or another topic.
#
# **Step 3: Develop a Question-Answering System**
#
# Create a question-answering system that uses the knowledge base and NLP module to provide relevant answers to user queries. This system can be based on a simple if-else statement or a more complex machine learning model.
#
# **Example Code**
#
# Here's an example code in Python that demonstrates how you can implement a basic question-answering system:
# ```python
# import nltk
# from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
#
# # Define a knowledge base
# knowledge_base = {
#     "depression": {
#         "symptoms": "Feeling sad, empty, or hopeless.",
#         "causes": "Genetics, brain chemistry, life events.",
#         "treatment": "Medication, therapy, lifestyle changes."
#     },
#     "daydreaming": {
#         "definition": "A state of mind where a person is distracted from the present moment.",
#         "causes": "Lack of focus, boredom, stress.",
#         "strategies": "Practice mindfulness, set goals, engage in activities."
#     },
#     "overthinking": {
#         "definition": "A state of mind where a person excessively thinks about a particular topic.",
#         "causes": "Anxiety, stress, perfectionism.",
#         "strategies": "Practice relaxation techniques, challenge negative thoughts, engage in physical activity."
#     }
# }
#
# # Define a function to analyze user input
# def analyze_input(user_input):
#     tokens = word_tokenize(user_input)
#     tokens = [token.lower() for token in tokens if token.isalpha()]
#     stop_words = set(stopwords.words("english"))
#     tokens = [token for token in tokens if token not in stop_words]
#     return tokens
#
# # Define a function to provide answers
# def provide_answer(tokens):
#     for token in tokens:
#         if token in knowledge_base:
#             return knowledge_base[token]
#     return "Sorry, I couldn't find any information on that topic."
#
# # Test the code
# user_input = "How can I overcome daydreaming?"
# tokens = analyze_input(user_input)
# answer = provide_answer(tokens)
# print(answer)
# ```
# This code defines a knowledge base with information on depression, daydreaming, and overthinking. It also includes a function to analyze user input and provide relevant answers. The `analyze_input` function uses NLTK to tokenize the user input and remove stop words. The `provide_answer` function checks if the tokens match any topics in the knowledge base and returns the corresponding information.
#
# **Note**: This is a basic example, and you can improve the code by adding more topics to the knowledge base, using more advanced NLP techniques, and implementing a more sophisticated question-answering system.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 17
#      14     if res.content:
#      15         chat()
# ---> 17 chat()
#
# Cell In[9], line 15, in chat()
#      13 print(res.content)
#      14 if res.content:
# ---> 15     chat()
#
# Cell In[9], line 15, in chat()
#      13 print(res.content)
#      14 if res.content:
# ---> 15     chat()
#
# Cell In[9], line 11, in chat()
#      10 def chat():
# ---> 11     userPrompt = input("Ask me something!")
#      12     res = llm.invoke(userPrompt)
#      13     print(res.content)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
